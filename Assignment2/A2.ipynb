# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

data = {
    "Student_ID": range(1, 51),
    "Gender": np.random.choice(["Male", "Female"], 50),
    "Age": np.random.randint(18, 25, 50),
    "Study_Hours": np.random.normal(5, 2, 50).round(1),
    "Attendance": np.random.randint(60, 101, 50),
    "Internal_Marks": np.random.randint(0, 50, 50),
    "Final_Marks": np.random.randint(0, 100, 50),
    "Grade": np.random.choice(["A", "B", "C", "D", None], 50)
}

df = pd.DataFrame(data)

# Introduce missing values intentionally
df.loc[5, "Study_Hours"] = np.nan
df.loc[12, "Attendance"] = np.nan
df.loc[20, "Internal_Marks"] = np.nan
df.loc[32, "Internal_Marks"] = 70
df.loc[29, "Internal_Marks"] =  90
df.loc[5, "Final_Marks"] = 210
df.loc[37, "Final_Marks"] = 190
df.to_csv("studentperformance.csv", index=False)
print("studentperformance.csv created successfully")
# Out:
# studentperformance.csv created successfully

# %%
print(df.to_string())
# Out:
#     Student_ID  Gender  Age  Study_Hours  Attendance  Internal_Marks  Final_Marks Grade
# 0            1    Male   24          0.6        87.0             3.0           47     C
# 1            2  Female   23          2.9        61.0            10.0           11  None
# 2            3    Male   20          5.3        65.0            16.0           68     C
# 3            4    Male   21          5.6        87.0            37.0           36     C
# 4            5    Male   24          6.5        87.0            23.0           31     C
# 5            6  Female   21          NaN        79.0             4.0          210     B
# 6            7    Male   18          6.1        89.0            33.0           98  None
# 7            8    Male   20          5.1        70.0             5.0           18     A
# 8            9    Male   22          5.9        87.0            21.0           47     D
# 9           10  Female   20          6.3        84.0            10.0           79     A
# ...

# %%
df.isnull().sum().count()
# Out:
# np.int64(8)

# %%
df.isnull().sum()
# Out:
# Student_ID         0
# Gender             0
# Age                0
# Study_Hours        1
# Attendance         1
# Internal_Marks     1
# Final_Marks        0
# Grade             11
# dtype: int64

# %%
df.replace(['None'],np.nan,inplace = True)

# %%
df.head(5)
# Out:
#    Student_ID  Gender  Age  Study_Hours  Attendance  Internal_Marks  \
# 0           1    Male   24          0.6        87.0             3.0
# 1           2  Female   23          2.9        61.0            10.0
# 2           3    Male   20          5.3        65.0            16.0
# 3           4    Male   21          5.6        87.0            37.0
# 4           5    Male   24          6.5        87.0            23.0
#
#    Final_Marks Grade
# 0           47     C
# 1           11  None
# 2           68     C
# 3           36     C
# 4           31     C

# %%
df['Study_Hours'] = pd.to_numeric(df['Study_Hours'],errors = 'coerce')
df['Attendance'] = pd.to_numeric(df['Attendance'],errors = 'coerce')
df['Internal_Marks'] = pd.to_numeric(df['Internal_Marks'],errors = 'coerce')

# %%
df.dtypes
# Out:
# Student_ID          int64
# Gender             object
# Age                 int64
# Study_Hours       float64
# Attendance        float64
# Internal_Marks    float64
# Final_Marks         int64
# Grade              object
# dtype: object

# %%
df['Study_Hours'] = df['Study_Hours'].fillna(df['Study_Hours'].mean())
df['Attendance'] = df['Attendance'].fillna(df['Attendance'].moutlier_indices = np.where((df_diabetics['bmi'] > 0.12) & (df_diabetics['bp'] < 0.8))

no_outliers = df_diabetics.drop(outlier_indices[0])ean())
df['Internal_Marks'] = df['Internal_Marks'].fillna(df['Internal_Marks'].mean())
df = df.fillna({"Grade": "C"})

df.head(5)
# Out:
#   Cell In[10], line 2
#     df['Attendance'] = df['Attendance'].fillna(df['Attendance'].moutlier_indices = np.where((df_diabetics['bmi'] > 0.12) & (df_diabetics['bp'] < 0.8))
#                                                ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
df.isnull().sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.boxplot(y='Internal_Marks', data=df)
plt.title('Box Plot to Find Outliers')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y='Final_Marks', data=df)
plt.title('Box Plot to Find Outliers')
plt.show()

# %%
outlier_indices = np.where((df['Internal_Marks'] < 0) | (df['Internal_Marks'] > 50))
no_outliers = df.drop(outlier_indices[0])
plt.figure(figsize=(8, 6))
sns.boxplot(y='Internal_Marks', data=no_outliers)
plt.title('Box Plot to Without Outliers(Internal Marks)')
plt.show()

# %%
outlier_indices1 = np.where((df['Final_Marks'] < 0  ) | (df['Final_Marks'] > 100)) 

no_outliers1 = df.drop(outlier_indices1[0])

plt.figure(figsize=(8,6))
sns.boxplot(y = 'Final_Marks' , data = no_outliers1)
plt.title('Box Plot Without Outliers(Final Marks)')
plt.show()

# %%
plt.figure(figsize=(10,4))

for i in ['Final_Marks']:
    sns.histplot(df[i], kde=True)
    sns.despine()
    plt.show()
    print("\n\n")

# %%
plt.figure(figsize=(10,4))

for i in ['Internal_Marks']:
    sns.histplot(df[i], kde=True)
    sns.despine()
    plt.show()
    print("\n\n")
